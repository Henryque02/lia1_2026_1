# %% [markdown]
# ##### <hr style="height:10px">
#
# <div class='container2'>
# 		<div>
# 			<img src='assets\header.png' ALIGN='left' style='width:10em'>
# 		</div>
# 	<div style='padding: 0 7em 2em 12em;'>
# 	<h1>Laboratório de Inovação e Automação 1 (LIA 1)</h1>
# 	<div style="font-size:12pt;float:left;"> 2026/1 | 24M34 | Sala 200 CAE</div><br><br>
#     <div style="font-size:12pt;float:left;"><b>Projetos de Inteligência Artificial</b></div>
# 	</div>
# </div>
#
#
#  <hr style="height:5px">
#
#
# <h2>Introdução ao Ambiente de Projetos - Python</h2>
#
# Notebook desenvolvido por: <a href="http://lattes.cnpq.br/1346824250595330">Prof. Dr. Adriano C. Santana</a>
#
#  <hr style="height:2px">

# %% [markdown]
# [Tudo sobre o Python, clique aqui!](https://docs.python.org/pt-br/3/tutorial/)

# %%
from platform import python_version
print(f'A versão em uso é {python_version()}.')
# Out:
# A versão em uso é 3.12.12.

# %%
python_version()
# Out:
# '3.12.12'

# %%
# Verificar se o Python está funcionando
print('Bye bye, World!')
# Out:
# Bye bye, World!

# %% [markdown]
# #### Operadores Aritméticos

# %%
# Adição
1 + 1
# Out:
# 2

# %%
# Subtração
2 - 1
# Out:
# 1

# %%
# Multiplicação
2 * 2
# Out:
# 4

# %%
# Divisão
3 / 2
# Out:
# 1.5

# %%
# Potência
4 ** 2
# Out:
# 16

# %%
# Módulo (resto da divisão)
10 % 3
# Out:
# 1

# %% [markdown]
# #### Tipo de Dados (Type)

# %%
# Qual o tipo do (?) -> Inteiro
type(5)
# Out:
# int

# %%
# Qual o tipo do (?) -> Float - Decimal
type(5.0)
# Out:
# float

# %%
# Qual o tipo do (?) -> String
a = 'Estudando Python!'
type(a)
# Out:
# str

# %% [markdown]
# #### Condicional if

# %%
# Condicional if (Se)
if 5 > 2:
    print("A sentença é verdadeira!")
# Out:
# A sentença é verdadeira!

# %%
# Condicional if...else
if 5 < 2:
    print("A sentença é verdadeira!")
else:
    print("A sentença é falsa!")
# Out:
# A sentença é falsa!

# %%
# Condicional if...else com variável
dia = "Quarta-feira"
if dia == "Sexta-feira":
    print("Hoje fará sol!")
else:
    print("Hoje vai chover!")
# Out:
# Hoje vai chover!

# %% [markdown]
# #### Manipulando arquivos

# %% [markdown]
# ##### Lendo arquivos (.txt)

# %%
# Abrindo o arquivo para leitura
a1 = open("assets/arquivo1_18_08.txt", "r")

# %%
# Lendo o arquivo
print(a1.read())
# Out:
# teste

# %% [markdown]
# ##### Gravando arquivos (.txt)

# %%
# Abrindo o arquivo para gravação
a2 = open("assets/arquivo2_18_08.txt", "w")

# %%
# Gravando no arquivo
a2.write("Aprendendo Python em 2025/2 com o ar condicionado no 12g!")
# Out:
# 57

# %%
# Abrindo o arquivo para leitura
a2 = open("assets/arquivo2_18_08.txt", "r")

# %%
# Imprimindo arquivo
print(a2.read())
# Out:
# Aprendendo Python em 2025/2 com o ar condicionado no 12g!
